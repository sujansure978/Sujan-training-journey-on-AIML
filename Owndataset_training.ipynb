# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\SUJAN SURE\OneDrive\Desktop\AIML-3\virtual\Scripts\loan_dataset.csv")
df.head(5)
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='str')

# %%
year_salary =df.groupby("Self_Employed")[['ApplicantIncome']].mean()
print("\nAverage  Self_Employed by ApplicantIncome:")
print(year_salary)
plt.Figure(figsize=(7,5))
plt.plot(
    year_salary.index,
    year_salary.values,
    marker="o"
)
plt.title("average of ApplicantIncome by Self_Employed")
plt.xlabel=("Self_Employed")
plt.ylabel=("avreage ApplicantIncome")
plt.grid(True)
plt.show()
# Out:
# Average  Self_Employed by ApplicantIncome:
#                ApplicantIncome
# Self_Employed
# No                 5049.748000
# Yes                7380.817073

# %%
avg_salary =df.groupby("Self_Employed")['ApplicantIncome'].mean()
plt.Figure(figsize=(7,5))
plt.bar(avg_salary.index,avg_salary.values,color=['green','yellow'])
plt.title("average of ApplicantIncome by Self_Employed")
plt.xlabel=("Self_Employed")
plt.ylabel=("average ApplicantIncome")
plt.show()

# %%
import pandas
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("diamonds")
print(df.head())
numeric_id=df.select_dtypes(include=["number"])
corr=numeric_id.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True,cmap="coolwarm",fmt=".2f")
plt.title("Correlation Heatmap of Numeric Features in diamonds Dataset")
plt.show()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\SUJAN SURE\OneDrive\Desktop\AIML-3\virtual\Scripts\Cyber_salaries.csv")
df.head(5)
#df.columns
# Out:
#    work_year experience_level employment_type                     job_title  \
# 0       2022               EN              FT  Information Security Officer
# 1       2022               SE              FT              Security Officer
# 2       2022               SE              FT              Security Officer
# 3       2022               SE              FT             Security Engineer
# 4       2022               SE              FT             Security Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   68000             EUR          72762                 DE           100
# 1  123400             USD         123400                 US             0
# 2   88100             USD          88100                 US             0
# 3  163575             USD         163575                 US           100
# 4  115800             USD         115800                 US           100
#
#   company_location company_size
# ...

# %%
import pandas
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\SUJAN SURE\OneDrive\Desktop\AIML-3\virtual\Scripts\Cyber_salaries.csv")
print(df.head())
numeric_id=df.select_dtypes(include=["number"])
corr=numeric_id.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True,cmap="coolwarm",fmt=".2f")
plt.title("Correlation Heatmap of Numeric Features in diamonds Dataset")
plt.show()
# Out:
#    work_year experience_level employment_type                     job_title  \
# 0       2022               EN              FT  Information Security Officer
# 1       2022               SE              FT              Security Officer
# 2       2022               SE              FT              Security Officer
# 3       2022               SE              FT             Security Engineer
# 4       2022               SE              FT             Security Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   68000             EUR          72762                 DE           100
# 1  123400             USD         123400                 US             0
# 2   88100             USD          88100                 US             0
# 3  163575             USD         163575                 US           100
# 4  115800             USD         115800                 US           100
#
#   company_location company_size
# ...

# %%
avg_salary =df.groupby("employee_residence")['salary'].mean()
plt.Figure(figsize=(7,5))
plt.bar(avg_salary.index,avg_salary.values,color=['green','yellow'])
plt.title("Group By Employee Residence to Salary")
plt.xlabel=("Employee Residence")
plt.ylabel=("salary")
plt.show()

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1344    False
# 1345    False
# 1346    False
# 1347    False
# 1348    False
# Length: 1349, dtype: bool

# %%
df.to_csv("Preprocessed data.csv",index=False)
print("Saved")
# Out:
# Saved

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv(r"C:\Users\SUJAN SURE\OneDrive\Desktop\AIML-3\virtual\Scripts\Preprocessed data.csv")
df.head()
# Out:
#    work_year experience_level employment_type                     job_title  \
# 0       2022               EN              FT  Information Security Officer
# 1       2022               SE              FT              Security Officer
# 2       2022               SE              FT              Security Officer
# 3       2022               SE              FT             Security Engineer
# 4       2022               SE              FT             Security Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   68000             EUR          72762                 DE           100
# 1  123400             USD         123400                 US             0
# 2   88100             USD          88100                 US             0
# 3  163575             USD         163575                 US           100
# 4  115800             USD         115800                 US           100
#
#   company_location company_size
# ...

# %%
X=df.drop("salary",axis=1)
y=df["salary"]
X=pd.get_dummies(X,drop_first=True)
X_train,X_test,y_train,y_test=train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)
print("Training Features: ",X_train.shape)
print("Testing Features: ",X_test.shape)
print("Training Target: ",y_train.shape)
print("Testing Target: ",y_test.shape)
print("\nTraining Data")
print(X_train.head())
print("\n Testing Data")
print(X_test.head())
# Out:
# Training Features:  (1079, 232)
# Testing Features:  (270, 232)
# Training Target:  (1079,)
# Testing Target:  (270,)
#
# Training Data
#       work_year  salary_in_usd  remote_ratio  experience_level_EX  \
# 755        2022         130000           100                False
# 109        2022         140000           100                False
# 1040       2021         130000             0                False
# 548        2022         260000           100                False
# 1341       2021         135000           100                False
#
#       experience_level_MI  experience_level_SE  employment_type_FL  \
# 755                  True                False               False
# 109                 False                 True               False
# 1040                False                 True               False
# 548                 False                 True               False
# 1341                False                 True               False
#
# ...
